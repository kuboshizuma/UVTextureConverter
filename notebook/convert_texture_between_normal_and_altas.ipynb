# %% [markdown]
# # Convert texture between normal and atlas
#
# - [1. Normal texture to Atlas texture](#1.-Normal-texture-to-Atlas-texture)
#     - [1.1. display normal texture](#1.1.-display-normal-texture)
#     - [1.2. convert](#1.2.-convert)
# - [2. Atlas texture to Normal texture](#2.-Atlas-texture-to-Normal-texture)
#     - [2.1. display atlas texture](#2.1.-display-atlas-texture)
#     - [2.2. convert](#2.2.-convert)

# %% [markdown]
# ## 1. Normal texture to Atlas texture

# %%
from UVTextureConverter import Normal2Atlas
from UVTextureConverter import Atlas2Normal
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 1.1. display normal texture

# %%
normal_tex = np.array(Image.open("../input/normal.jpg"))
plt.imshow(normal_tex)

# %% [markdown]
# ## 1.2. convert

# %%
converter = Normal2Atlas(normal_size=512, atlas_size=200)
atlas_texture = converter.convert(normal_tex)

# for display
plt.imshow(Normal2Atlas.concat_atlas_tex(atlas_texture))

# %% [markdown]
# # 2. Atlas texture to Normal texture

# %% [markdown]
# ## 2.1. display atlas texture

# %%
im = np.array(Image.open("../input/atlas.png").convert('RGB')).transpose(1, 0, 2)

# %%
plt.imshow(im)

# %% [markdown]
# ## 2.2. convert

# %%
# for stack
atlas_tex_stack = Atlas2Normal.split_atlas_tex(im)

converter = Atlas2Normal(atlas_size=200, normal_size=512)
normal_tex = converter.convert(atlas_tex_stack)
plt.imshow(normal_tex)
